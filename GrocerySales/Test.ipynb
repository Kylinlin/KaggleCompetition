# %%
import pandas as pd
import numpy as np
from datetime import date, timedelta

# %%
t_2017 = date(2017,5,31)
for i in range(6):
    delta = timedelta(days = 7 * i)
    print(t_2017 + delta)
# Out:
# 2017-05-31
# 2017-06-07
# 2017-06-14
# 2017-06-21
# 2017-06-28
# 2017-07-05

# %%
df_2017 = date(2017,5,31)
for i in range(7):
    t = pd.date_range(df_2017 - timedelta(28-i), periods=4, freq='7D')
    print(t)
# Out:
# DatetimeIndex(['2017-05-03', '2017-05-10', '2017-05-17', '2017-05-24'], dtype='datetime64[ns]', freq='7D')
# DatetimeIndex(['2017-05-04', '2017-05-11', '2017-05-18', '2017-05-25'], dtype='datetime64[ns]', freq='7D')
# DatetimeIndex(['2017-05-05', '2017-05-12', '2017-05-19', '2017-05-26'], dtype='datetime64[ns]', freq='7D')
# DatetimeIndex(['2017-05-06', '2017-05-13', '2017-05-20', '2017-05-27'], dtype='datetime64[ns]', freq='7D')
# DatetimeIndex(['2017-05-07', '2017-05-14', '2017-05-21', '2017-05-28'], dtype='datetime64[ns]', freq='7D')
# DatetimeIndex(['2017-05-08', '2017-05-15', '2017-05-22', '2017-05-29'], dtype='datetime64[ns]', freq='7D')
# DatetimeIndex(['2017-05-09', '2017-05-16', '2017-05-23', '2017-05-30'], dtype='datetime64[ns]', freq='7D')

# %%
pd.date_range(df_2017 - timedelta(0), periods=1)
# Out:
# DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', freq='D')

# %%
for i in range(7):
    t = pd.date_range(df_2017 - timedelta(140-i), periods=20, freq='7D')
    print(t)
# Out:
# DatetimeIndex(['2017-01-11', '2017-01-18', '2017-01-25', '2017-02-01',
#                '2017-02-08', '2017-02-15', '2017-02-22', '2017-03-01',
#                '2017-03-08', '2017-03-15', '2017-03-22', '2017-03-29',
#                '2017-04-05', '2017-04-12', '2017-04-19', '2017-04-26',
#                '2017-05-03', '2017-05-10', '2017-05-17', '2017-05-24'],
#               dtype='datetime64[ns]', freq='7D')
# DatetimeIndex(['2017-01-12', '2017-01-19', '2017-01-26', '2017-02-02',
#                '2017-02-09', '2017-02-16', '2017-02-23', '2017-03-02',
#                '2017-03-09', '2017-03-16', '2017-03-23', '2017-03-30',
#                '2017-04-06', '2017-04-13', '2017-04-20', '2017-04-27',
#                '2017-05-04', '2017-05-11', '2017-05-18', '2017-05-25'],
#               dtype='datetime64[ns]', freq='7D')
# DatetimeIndex(['2017-01-13', '2017-01-20', '2017-01-27', '2017-02-03',
#                '2017-02-10', '2017-02-17', '2017-02-24', '2017-03-03',
# ...

# %%
df_holiday = pd.read_csv('database/holidays_events.csv', 
                        parse_dates = ['date'],
                        dtype={'transferred':bool})

holiday_2017 = df_holiday.loc[df_holiday.date >= pd.datetime(2017,1,1)]
holiday_2017 = holiday_2017.loc[holiday_2017['transferred'] == False]
holiday_2017
# Out:
#           date        type    locale                     locale_name  \
# 298 2017-01-02    Transfer  National                         Ecuador
# 299 2017-02-27     Holiday  National                         Ecuador
# 300 2017-02-28     Holiday  National                         Ecuador
# 301 2017-03-02     Holiday     Local                           Manta
# 302 2017-04-01     Holiday  Regional                        Cotopaxi
# 304 2017-04-13    Transfer     Local                          Cuenca
# 305 2017-04-14     Holiday     Local                        Libertad
# 306 2017-04-14     Holiday  National                         Ecuador
# 307 2017-04-21     Holiday     Local                        Riobamba
# 308 2017-05-01     Holiday  National                         Ecuador
# 309 2017-05-12     Holiday     Local                            Puyo
# 310 2017-05-13  Additional  National                         Ecuador
# 311 2017-05-14       Event  National                         Ecuador
# ...

# %%
firstday = date(2017,1,1)
endday = date(2017,9,1)
periods = endday - firstday
all_days = pd.date_range(firstday, periods=periods.days, freq='D')

# %%
weekend_tmp = map(lambda day: True if(day.dayofweek >=5) else False, all_days)

weekend = []
for i in weekend_tmp:
    weekend.append(i)
    
df_weekend = pd.DataFrame({'date':all_days, 'weekend_or_holiday': weekend })
df_weekend
# Out:
#           date  weekend_or_holiday
# 0   2017-01-01                True
# 1   2017-01-02               False
# 2   2017-01-03               False
# 3   2017-01-04               False
# 4   2017-01-05               False
# 5   2017-01-06               False
# 6   2017-01-07                True
# 7   2017-01-08                True
# 8   2017-01-09               False
# 9   2017-01-10               False
# 10  2017-01-11               False
# 11  2017-01-12               False
# 12  2017-01-13               False
# 13  2017-01-14                True
# 14  2017-01-15                True
# 15  2017-01-16               False
# 16  2017-01-17               False
# 17  2017-01-18               False
# 18  2017-01-19               False
# 19  2017-01-20               False
# 20  2017-01-21                True
# 21  2017-01-22                True
# 22  2017-01-23               False
# 23  2017-01-24               False
# 24  2017-01-25               False
# 25  2017-01-26               False
# ...

# %%
tmp = holiday_2017['date'].values
for i in range(len(tmp)):
    df_weekend.loc[df_weekend['date'] == tmp[i], 'weekend_or_holiday'] = True

# %%
df_weekend
# Out:
#           date  weekend_or_holiday
# 0   2017-01-01                True
# 1   2017-01-02                True
# 2   2017-01-03               False
# 3   2017-01-04               False
# 4   2017-01-05               False
# 5   2017-01-06               False
# 6   2017-01-07                True
# 7   2017-01-08                True
# 8   2017-01-09               False
# 9   2017-01-10               False
# 10  2017-01-11               False
# 11  2017-01-12               False
# 12  2017-01-13               False
# 13  2017-01-14                True
# 14  2017-01-15                True
# 15  2017-01-16               False
# 16  2017-01-17               False
# 17  2017-01-18               False
# 18  2017-01-19               False
# 19  2017-01-20               False
# 20  2017-01-21                True
# 21  2017-01-22                True
# 22  2017-01-23               False
# 23  2017-01-24               False
# 24  2017-01-25               False
# 25  2017-01-26               False
# ...

# %%
df_store = pd.read_csv('database/stores.csv')
df_store
# Out:
#     store_nbr           city                           state type  cluster
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# ...

# %%
sotre_city = df_store['city'].unique()
sotre_city
# Out:
# array(['Quito', 'Santo Domingo', 'Cayambe', 'Latacunga', 'Riobamba',
#        'Ibarra', 'Guaranda', 'Puyo', 'Ambato', 'Guayaquil', 'Salinas',
#        'Daule', 'Babahoyo', 'Quevedo', 'Playas', 'Libertad', 'Cuenca',
#        'Loja', 'Machala', 'Esmeraldas', 'Manta', 'El Carmen'], dtype=object)

# %%
df_store['state'].unique()
# Out:
# array(['Pichincha', 'Santo Domingo de los Tsachilas', 'Cotopaxi',
#        'Chimborazo', 'Imbabura', 'Bolivar', 'Pastaza', 'Tungurahua',
#        'Guayas', 'Santa Elena', 'Los Rios', 'Azuay', 'Loja', 'El Oro',
#        'Esmeraldas', 'Manabi'], dtype=object)

# %%
len(df_store['city'].unique())
# Out:
# 22

# %%
citys = pd.read_csv('database/city_population.csv')
citys
# Out:
#                              Name  2017 Population
# 0                       Guayaquil          1952029
# 1                           Quito          1399814
# 2                          Cuenca           276964
# 3                   Santo Domingo           200421
# 4                         Machala           198123
# 5                           Manta           183166
# 6                      Portoviejo           170326
# 7                     Eloy Alfaro           167784
# 8                      Esmeraldas           165216
# 9                          Ambato           154369
# 10                Tutamandahostel           140000
# 11                         Ibarra           132977
# 12                       Riobamba           124478
# 13                        Quevedo           119436
# 14                           Loja           117796
# 15                         Tulcan            86498
# 16                       Babahoyo            76279
# ...

# %%
big_citys = citys[citys['2017 Population'] >= 1000000]['Name'].values
big_citys
# Out:
# array(['Guayaquil', 'Quito'], dtype=object)

# %%
middle_citys = citys.loc[(citys['2017 Population'] >= 100000) & (citys['2017 Population'] < 1000000)]['Name'].values
middle_citys
# Out:
# array(['Cuenca', 'Santo Domingo', 'Machala', 'Manta', 'Portoviejo',
#        'Eloy Alfaro', 'Esmeraldas', 'Ambato', 'Tutamandahostel', 'Ibarra',
#        'Riobamba', 'Quevedo', 'Loja'], dtype=object)

# %%
df_store['big_city'] = False
df_store['middle_city'] = False
df_store['little_city'] = False

# %%
df_store
# Out:
#     store_nbr           city                           state type  cluster  \
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# ...

# %%
df_store['big_city'] = df_store['city'].map(lambda u :True if u in big_citys else False).astype(bool)
df_store['middle_city'] = df_store['city'].map(lambda u: True if u in middle_citys else False).astype(bool)
df_store['little_city'] = df_store['city'].map(lambda u: True if u not in big_citys and u not in middle_citys else False).astype(bool)

# %%
df_store
# Out:
#     store_nbr           city                           state type  cluster  \
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# ...

# %%
df_store = df_store[['store_nbr', 'big_city','middle_city','little_city']]
df_store
# Out:
#     store_nbr  big_city  middle_city  little_city
# 0           1      True        False        False
# 1           2      True        False        False
# 2           3      True        False        False
# 3           4      True        False        False
# 4           5     False         True        False
# 5           6      True        False        False
# 6           7      True        False        False
# 7           8      True        False        False
# 8           9      True        False        False
# 9          10      True        False        False
# 10         11     False        False         True
# 11         12     False        False         True
# 12         13     False        False         True
# 13         14     False         True        False
# 14         15     False         True        False
# 15         16     False         True        False
# 16         17      True        False        False
# 17         18      True        False        False
# ...

# %%
df_items = pd.read_csv('database/items.csv')
df_items
# Out:
#       item_nbr            family  class  perishable
# 0        96995         GROCERY I   1093           0
# 1        99197         GROCERY I   1067           0
# 2       103501          CLEANING   3008           0
# 3       103520         GROCERY I   1028           0
# 4       103665      BREAD/BAKERY   2712           1
# 5       105574         GROCERY I   1045           0
# 6       105575         GROCERY I   1045           0
# 7       105576         GROCERY I   1045           0
# 8       105577         GROCERY I   1045           0
# 9       105693         GROCERY I   1034           0
# 10      105737         GROCERY I   1044           0
# 11      105857         GROCERY I   1092           0
# 12      106716         GROCERY I   1032           0
# 13      108079         GROCERY I   1030           0
# 14      108634         GROCERY I   1075           0
# 15      108696              DELI   2636           1
# 16      108698              DELI   2644           1
# ...

# %%
df_items['family_nbr'] = df_items['family'].astype('category').cat.codes

# %%
df_items.head()
# Out:
#    item_nbr        family  class  perishable  family_nbr
# 0     96995     GROCERY I   1093           0          12
# 1     99197     GROCERY I   1067           0          12
# 2    103501      CLEANING   3008           0           7
# 3    103520     GROCERY I   1028           0          12
# 4    103665  BREAD/BAKERY   2712           1           5

# %%
df_items['class_nbr'] = df_items['class'].astype('category').cat.codes
df_items.head()
# Out:
#    item_nbr        family  class  perishable  family_nbr  class_nbr
# 0     96995     GROCERY I   1093           0          12         64
# 1     99197     GROCERY I   1067           0          12         44
# 2    103501      CLEANING   3008           0           7        217
# 3    103520     GROCERY I   1028           0          12         17
# 4    103665  BREAD/BAKERY   2712           1           5        187

# %%
df_items
# Out:
#       item_nbr            family  class  perishable  family_nbr  class_nbr
# 0        96995         GROCERY I   1093           0          12         64
# 1        99197         GROCERY I   1067           0          12         44
# 2       103501          CLEANING   3008           0           7        217
# 3       103520         GROCERY I   1028           0          12         17
# 4       103665      BREAD/BAKERY   2712           1           5        187
# 5       105574         GROCERY I   1045           0          12         31
# 6       105575         GROCERY I   1045           0          12         31
# 7       105576         GROCERY I   1045           0          12         31
# 8       105577         GROCERY I   1045           0          12         31
# 9       105693         GROCERY I   1034           0          12         22
# 10      105737         GROCERY I   1044           0          12         30
# ...

# %%
df_test = pd.read_csv('database/test.csv', dtype={'onpromotion':bool},
                     parse_dates = ['date'],usecols=[0,1,2,3,4])

# %%
df_test.head()
# Out:
#           id       date  store_nbr  item_nbr  onpromotion
# 0  125497040 2017-08-16          1     96995        False
# 1  125497041 2017-08-16          1     99197        False
# 2  125497042 2017-08-16          1    103501        False
# 3  125497043 2017-08-16          1    103520        False
# 4  125497044 2017-08-16          1    103665        False

# %%
item_2017_test = pd.merge(df_test, df_items[['item_nbr', 'family_nbr', 'class_nbr']], how='left', on=['item_nbr'])
item_2017_test
# Out:
#                 id       date  store_nbr  item_nbr  onpromotion  family_nbr  \
# 0        125497040 2017-08-16          1     96995        False          12
# 1        125497041 2017-08-16          1     99197        False          12
# 2        125497042 2017-08-16          1    103501        False           7
# 3        125497043 2017-08-16          1    103520        False          12
# 4        125497044 2017-08-16          1    103665        False           5
# 5        125497045 2017-08-16          1    105574        False          12
# 6        125497046 2017-08-16          1    105575        False          12
# 7        125497047 2017-08-16          1    105576        False          12
# 8        125497048 2017-08-16          1    105577        False          12
# 9        125497049 2017-08-16          1    105693        False          12
# 10       125497050 2017-08-16          1    105737        False          12
# ...

# %%
item_2017_test.reindex()

# %%
item_2017_train = pd.merge(df_2017, df_items[['item_nbr', 'family_nbr', 'class_nbr']], how='left', on=['item_nbr'])
item_2017_train.set_index(['store_nbr', 'item_nbr', 'date'])

item_2017_test = pd.merge(df_test, df_items[['item_nbr', 'family_nbr', 'class_nbr']], how='left', on=['item_nbr'])
item_2017_test.reindex(item_2017_train.index)

# %%
def getItemCategory(df):
    df

# %%
df_items['family']
# Out:
# 0              GROCERY I
# 1              GROCERY I
# 2               CLEANING
# 3              GROCERY I
# 4           BREAD/BAKERY
# 5              GROCERY I
# 6              GROCERY I
# 7              GROCERY I
# 8              GROCERY I
# 9              GROCERY I
# 10             GROCERY I
# 11             GROCERY I
# 12             GROCERY I
# 13             GROCERY I
# 14             GROCERY I
# 15                  DELI
# 16                  DELI
# 17                  DELI
# 18              CLEANING
# 19             GROCERY I
# 20               POULTRY
# 21                  EGGS
# 22             GROCERY I
# 23              CLEANING
# 24             GROCERY I
# 25             GROCERY I
# 26             GROCERY I
# 27             GROCERY I
# 28             GROCERY I
# 29         PERSONAL CARE
#               ...
# 4070           GROCERY I
# 4071           BEVERAGES
# 4072           BEVERAGES
# 4073           GROCERY I
# 4074           GROCERY I
# 4075           GROCERY I
# ...

# %%
t = pd.concat([df_items['family']] * 4)
t
# Out:
# 0              GROCERY I
# 1              GROCERY I
# 2               CLEANING
# 3              GROCERY I
# 4           BREAD/BAKERY
# 5              GROCERY I
# 6              GROCERY I
# 7              GROCERY I
# 8              GROCERY I
# 9              GROCERY I
# 10             GROCERY I
# 11             GROCERY I
# 12             GROCERY I
# 13             GROCERY I
# 14             GROCERY I
# 15                  DELI
# 16                  DELI
# 17                  DELI
# 18              CLEANING
# 19             GROCERY I
# 20               POULTRY
# 21                  EGGS
# 22             GROCERY I
# 23              CLEANING
# 24             GROCERY I
# 25             GROCERY I
# 26             GROCERY I
# 27             GROCERY I
# 28             GROCERY I
# 29         PERSONAL CARE
#               ...
# 4070           GROCERY I
# 4071           BEVERAGES
# 4072           BEVERAGES
# 4073           GROCERY I
# 4074           GROCERY I
# 4075           GROCERY I
# ...

# %%
df_store
# Out:
#     store_nbr  big_city  middle_city  little_city
# 0           1      True        False        False
# 1           2      True        False        False
# 2           3      True        False        False
# 3           4      True        False        False
# 4           5     False         True        False
# 5           6      True        False        False
# 6           7      True        False        False
# 7           8      True        False        False
# 8           9      True        False        False
# 9          10      True        False        False
# 10         11     False        False         True
# 11         12     False        False         True
# 12         13     False        False         True
# 13         14     False         True        False
# 14         15     False         True        False
# 15         16     False         True        False
# 16         17      True        False        False
# 17         18      True        False        False
# ...

# %%
df_store = pd.read_csv('database/stores.csv')
df_store
# Out:
#     store_nbr           city                           state type  cluster
# 0           1          Quito                       Pichincha    D       13
# 1           2          Quito                       Pichincha    D       13
# 2           3          Quito                       Pichincha    D        8
# 3           4          Quito                       Pichincha    D        9
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas    D        4
# 5           6          Quito                       Pichincha    D       13
# 6           7          Quito                       Pichincha    D        8
# 7           8          Quito                       Pichincha    D        8
# 8           9          Quito                       Pichincha    B        6
# 9          10          Quito                       Pichincha    C       15
# 10         11        Cayambe                       Pichincha    B        6
# ...
